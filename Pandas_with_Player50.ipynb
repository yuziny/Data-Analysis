# %% [markdown]
# <a href="https://colab.research.google.com/github/yuziny/Data-Analysis/blob/main/Pandas_with_Player50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(
    {"이름":['손흥민','김민재','이강인'],
     '나이':[31, 27, 22],
     '소속':['토트넘','바이에른뮌헨','파리생제르망']
     }
)

# %%
df1
# Out:
#     이름  나이      소속
# 0  손흥민  31     토트넘
# 1  김민재  27  바이에른뮌헨
# 2  이강인  22  파리생제르망

# %%
player_list = [
        ['손흥민',31,'토트넘'],
        ['김민재',27,'바이에른뮌헨'],
        ['이강인',22,'파리생제르망']
]
df2 = pd.DataFrame(player_list, columns=['이름','나이','소속'])

# %%
df2
# Out:
#     이름  나이      소속
# 0  손흥민  31     토트넘
# 1  김민재  27  바이에른뮌헨
# 2  이강인  22  파리생제르망

# %%
pd.read_csv('/content/drive/MyDrive/data analysis/transfermarket50.csv')
# Out:
#     number                 name            position  age     nation  \
# 0        1      Jude Bellingham  Attacking Midfield   20    England
# 1        2       Erling Haaland      Centre-Forward   23     Norway
# 2        3        Kylian Mbappé         Left Winger   25     France
# 3        4      Vinicius Junior         Left Winger   23     Brazil
# 4        5          Bukayo Saka        Right Winger   22    England
# 5        6        Jamal Musiala  Attacking Midfield   20    Germany
# 6        7           Phil Foden        Right Winger   23    England
# 7        8     Lautaro Martínez      Centre-Forward   26  Argentina
# 8        9       Victor Osimhen      Centre-Forward   25    Nigeria
# 9       10          Declan Rice  Defensive Midfield   24    England
# 10      11                Rodri  Defensive Midfield   27      Spain
# 11      12           Harry Kane      Centre-Forward   30    England
# 12      13        Florian Wirtz  Attacking Midfield   20    Germany
# ...

# %%
# 데이터프레임을 df에 저장
df = pd.read_csv('/content/drive/MyDrive/data analysis/transfermarket50.csv')
df
# Out:
#     number                 name            position  age     nation  \
# 0        1      Jude Bellingham  Attacking Midfield   20    England
# 1        2       Erling Haaland      Centre-Forward   23     Norway
# 2        3        Kylian Mbappé         Left Winger   25     France
# 3        4      Vinicius Junior         Left Winger   23     Brazil
# 4        5          Bukayo Saka        Right Winger   22    England
# 5        6        Jamal Musiala  Attacking Midfield   20    Germany
# 6        7           Phil Foden        Right Winger   23    England
# 7        8     Lautaro Martínez      Centre-Forward   26  Argentina
# 8        9       Victor Osimhen      Centre-Forward   25    Nigeria
# 9       10          Declan Rice  Defensive Midfield   24    England
# 10      11                Rodri  Defensive Midfield   27      Spain
# 11      12           Harry Kane      Centre-Forward   30    England
# 12      13        Florian Wirtz  Attacking Midfield   20    Germany
# ...

# %% [markdown]
# DataFrame

# %%
df.shape
# Out:
# (25, 7)

# %%
(rows, columns) = df.shape

# %%
rows
# Out:
# 25

# %%
columns
# Out:
# 7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   number    25 non-null     int64
#  1   name      25 non-null     object
#  2   position  25 non-null     object
#  3   age       25 non-null     int64
#  4   nation    25 non-null     object
#  5   team      25 non-null     object
#  6   value     25 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 1.5+ KB

# %%
df.head()
# Out:
#    number             name            position  age   nation  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England
# 1       2   Erling Haaland      Centre-Forward   23   Norway
# 2       3    Kylian Mbappé         Left Winger   25   France
# 3       4  Vinicius Junior         Left Winger   23   Brazil
# 4       5      Bukayo Saka        Right Winger   22  England
#
#                   team     value
# 0          Real Madrid  €180.00m
# 1      Manchester City  €180.00m
# 2  Paris Saint-Germain  €180.00m
# 3          Real Madrid  €150.00m
# 4           Arsenal FC  €120.00m

# %%
df.tail()
# Out:
#     number                 name            position  age    nation  \
# 20      21  Aurélien Tchouaméni  Defensive Midfield   23    France
# 21      22          Rafael Leão         Left Winger   24  Portugal
# 22      23      Martin Ødegaard  Attacking Midfield   25    Norway
# 23      24   Gabriel Martinelli         Left Winger   22    Brazil
# 24      25      Bruno Guimarães  Defensive Midfield   26    Brazil
#
#                 team    value
# 20       Real Madrid  €90.00m
# 21          AC Milan  €90.00m
# 22        Arsenal FC  €90.00m
# 23        Arsenal FC  €85.00m
# 24  Newcastle United  €85.00m

# %%
df[:5]
# Out:
#    number             name            position  age   nation  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England
# 1       2   Erling Haaland      Centre-Forward   23   Norway
# 2       3    Kylian Mbappé         Left Winger   25   France
# 3       4  Vinicius Junior         Left Winger   23   Brazil
# 4       5      Bukayo Saka        Right Winger   22  England
#
#                   team     value
# 0          Real Madrid  €180.00m
# 1      Manchester City  €180.00m
# 2  Paris Saint-Germain  €180.00m
# 3          Real Madrid  €150.00m
# 4           Arsenal FC  €120.00m

# %%
df['name'].head()
# Out:
# 0    Jude Bellingham
# 1     Erling Haaland
# 2      Kylian Mbappé
# 3    Vinicius Junior
# 4        Bukayo Saka
# Name: name, dtype: object

# %%
# 여러개 컬럼 이름 선택
df[['number','name','nation']].head()
# Out:
#    number             name   nation
# 0       1  Jude Bellingham  England
# 1       2   Erling Haaland   Norway
# 2       3    Kylian Mbappé   France
# 3       4  Vinicius Junior   Brazil
# 4       5      Bukayo Saka  England

# %%
df.iloc[0:2] # df[0:2]
# Out:
#    number             name            position  age   nation             team  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England      Real Madrid
# 1       2   Erling Haaland      Centre-Forward   23   Norway  Manchester City
#
#       value
# 0  €180.00m
# 1  €180.00m

# %%
df.loc[0:2]
# Out:
#    number             name            position  age   nation  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England
# 1       2   Erling Haaland      Centre-Forward   23   Norway
# 2       3    Kylian Mbappé         Left Winger   25   France
#
#                   team     value
# 0          Real Madrid  €180.00m
# 1      Manchester City  €180.00m
# 2  Paris Saint-Germain  €180.00m

# %%
df.loc[0,'name'] # df.loc[행이름, 열이름]
# Out:
# 'Jude Bellingham'

# %%
df.loc[0:5, ['name','team','value']]
# Out:
#               name                 team     value
# 0  Jude Bellingham          Real Madrid  €180.00m
# 1   Erling Haaland      Manchester City  €180.00m
# 2    Kylian Mbappé  Paris Saint-Germain  €180.00m
# 3  Vinicius Junior          Real Madrid  €150.00m
# 4      Bukayo Saka           Arsenal FC  €120.00m
# 5    Jamal Musiala        Bayern Munich  €110.00m

# %%
df['age'] <= 20
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# Name: age, dtype: bool

# %%
df[df['age']<=20]
# Out:
#     number             name            position  age   nation  \
# 0        1  Jude Bellingham  Attacking Midfield   20  England
# 5        6    Jamal Musiala  Attacking Midfield   20  Germany
# 12      13    Florian Wirtz  Attacking Midfield   20  Germany
# 17      18             Gavi    Central Midfield   19    Spain
#
#                    team     value
# 0           Real Madrid  €180.00m
# 5         Bayern Munich  €110.00m
# 12  Bayer 04 Leverkusen  €100.00m
# 17         FC Barcelona   €90.00m

# %%
df[df['team'] == 'Real Madrid']
# Out:
#     number                 name            position  age   nation  \
# 0        1      Jude Bellingham  Attacking Midfield   20  England
# 3        4      Vinicius Junior         Left Winger   23   Brazil
# 13      14              Rodrygo        Right Winger   22   Brazil
# 14      15    Federico Valverde    Central Midfield   25  Uruguay
# 18      19    Eduardo Camavinga    Central Midfield   21   France
# 20      21  Aurélien Tchouaméni  Defensive Midfield   23   France
#
#            team     value
# 0   Real Madrid  €180.00m
# 3   Real Madrid  €150.00m
# 13  Real Madrid  €100.00m
# 14  Real Madrid  €100.00m
# 18  Real Madrid   €90.00m
# 20  Real Madrid   €90.00m

# %%
df.loc[df['age']>=30, ['name','value']]
# Out:
#           name     value
# 11  Harry Kane  €110.00m

# %%
df.head()
df.sort_index().head()
# Out:
#    number             name            position  age   nation  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England
# 1       2   Erling Haaland      Centre-Forward   23   Norway
# 2       3    Kylian Mbappé         Left Winger   25   France
# 3       4  Vinicius Junior         Left Winger   23   Brazil
# 4       5      Bukayo Saka        Right Winger   22  England
#
#                   team     value
# 0          Real Madrid  €180.00m
# 1      Manchester City  €180.00m
# 2  Paris Saint-Germain  €180.00m
# 3          Real Madrid  €150.00m
# 4           Arsenal FC  €120.00m

# %%
df.sort_index(ascending=False)[:5]
# Out:
#     number                 name            position  age    nation  \
# 24      25      Bruno Guimarães  Defensive Midfield   26    Brazil
# 23      24   Gabriel Martinelli         Left Winger   22    Brazil
# 22      23      Martin Ødegaard  Attacking Midfield   25    Norway
# 21      22          Rafael Leão         Left Winger   24  Portugal
# 20      21  Aurélien Tchouaméni  Defensive Midfield   23    France
#
#                 team    value
# 24  Newcastle United  €85.00m
# 23        Arsenal FC  €85.00m
# 22        Arsenal FC  €90.00m
# 21          AC Milan  €90.00m
# 20       Real Madrid  €90.00m

# %%
df.sort_values('age', ascending=False).head()
# Out:
#     number               name            position  age     nation  \
# 11      12         Harry Kane      Centre-Forward   30    England
# 10      11              Rodri  Defensive Midfield   27      Spain
# 7        8   Lautaro Martínez      Centre-Forward   26  Argentina
# 24      25    Bruno Guimarães  Defensive Midfield   26     Brazil
# 14      15  Federico Valverde    Central Midfield   25    Uruguay
#
#                 team     value
# 11     Bayern Munich  €110.00m
# 10   Manchester City  €110.00m
# 7        Inter Milan  €110.00m
# 24  Newcastle United   €85.00m
# 14       Real Madrid  €100.00m

# %%
df.set_index('number').head()
# Out:
#                    name            position  age   nation  \
# number
# 1       Jude Bellingham  Attacking Midfield   20  England
# 2        Erling Haaland      Centre-Forward   23   Norway
# 3         Kylian Mbappé         Left Winger   25   France
# 4       Vinicius Junior         Left Winger   23   Brazil
# 5           Bukayo Saka        Right Winger   22  England
#
#                        team     value
# number
# 1               Real Madrid  €180.00m
# 2           Manchester City  €180.00m
# 3       Paris Saint-Germain  €180.00m
# 4               Real Madrid  €150.00m
# 5                Arsenal FC  €120.00m

# %%
df.head()
# Out:
#    number             name            position  age   nation  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England
# 1       2   Erling Haaland      Centre-Forward   23   Norway
# 2       3    Kylian Mbappé         Left Winger   25   France
# 3       4  Vinicius Junior         Left Winger   23   Brazil
# 4       5      Bukayo Saka        Right Winger   22  England
#
#                   team     value
# 0          Real Madrid  €180.00m
# 1      Manchester City  €180.00m
# 2  Paris Saint-Germain  €180.00m
# 3          Real Madrid  €150.00m
# 4           Arsenal FC  €120.00m

# %%
df.rename(columns = {'team':'club'}, inplace=True)

# %%
df.head()
# Out:
#    number             name            position  age   nation  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England
# 1       2   Erling Haaland      Centre-Forward   23   Norway
# 2       3    Kylian Mbappé         Left Winger   25   France
# 3       4  Vinicius Junior         Left Winger   23   Brazil
# 4       5      Bukayo Saka        Right Winger   22  England
#
#                   club     value
# 0          Real Madrid  €180.00m
# 1      Manchester City  €180.00m
# 2  Paris Saint-Germain  €180.00m
# 3          Real Madrid  €150.00m
# 4           Arsenal FC  €120.00m

# %%
# value값에서 불필요한 문자 없애고, 데이터 타입을 숫자형으로 바꾸기
df['value'] = df['value'].str.replace('€','')
df['value'] = df['value'].str.replace('m','').astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   number    25 non-null     int64
#  1   name      25 non-null     object
#  2   position  25 non-null     object
#  3   age       25 non-null     int64
#  4   nation    25 non-null     object
#  5   club      25 non-null     object
#  6   value     25 non-null     float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.5+ KB

# %%
df.head()
# Out:
#    number             name            position  age   nation  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England
# 1       2   Erling Haaland      Centre-Forward   23   Norway
# 2       3    Kylian Mbappé         Left Winger   25   France
# 3       4  Vinicius Junior         Left Winger   23   Brazil
# 4       5      Bukayo Saka        Right Winger   22  England
#
#                   club  value
# 0          Real Madrid  180.0
# 1      Manchester City  180.0
# 2  Paris Saint-Germain  180.0
# 3          Real Madrid  150.0
# 4           Arsenal FC  120.0

# %%
df['시장가치(억)'] = df['value']*13
df.head()
# Out:
#    number             name            position  age   nation  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England
# 1       2   Erling Haaland      Centre-Forward   23   Norway
# 2       3    Kylian Mbappé         Left Winger   25   France
# 3       4  Vinicius Junior         Left Winger   23   Brazil
# 4       5      Bukayo Saka        Right Winger   22  England
#
#                   club  value  시장가치(억)
# 0          Real Madrid  180.0   2340.0
# 1      Manchester City  180.0   2340.0
# 2  Paris Saint-Germain  180.0   2340.0
# 3          Real Madrid  150.0   1950.0
# 4           Arsenal FC  120.0   1560.0

# %%
df.drop(columns=['value'],inplace=True)

# %%
df.head()
# Out:
#    number             name            position  age   nation  \
# 0       1  Jude Bellingham  Attacking Midfield   20  England
# 1       2   Erling Haaland      Centre-Forward   23   Norway
# 2       3    Kylian Mbappé         Left Winger   25   France
# 3       4  Vinicius Junior         Left Winger   23   Brazil
# 4       5      Bukayo Saka        Right Winger   22  England
#
#                   club  시장가치(억)
# 0          Real Madrid   2340.0
# 1      Manchester City   2340.0
# 2  Paris Saint-Germain   2340.0
# 3          Real Madrid   1950.0
# 4           Arsenal FC   1560.0

# %%
df.describe()
# Out:
#           number        age      시장가치(억)
# count  25.000000  25.000000    25.000000
# mean   13.000000  23.240000  1440.400000
# std     7.359801   2.537716   385.770117
# min     1.000000  19.000000  1105.000000
# 25%     7.000000  22.000000  1170.000000
# 50%    13.000000  23.000000  1300.000000
# 75%    19.000000  25.000000  1430.000000
# max    25.000000  30.000000  2340.000000

# %%
df['age'].mean()
# Out:
# 23.24

# %%
df['시장가치(억)'].sum()
# Out:
# 36010.0

# %%
df['nation'].mode()
# Out:
# 0    England
# Name: nation, dtype: object

# %%
df[df['nation'] == 'Brazil']
# Out:
#     number                name            position  age  nation  \
# 3        4     Vinicius Junior         Left Winger   23  Brazil
# 13      14             Rodrygo        Right Winger   22  Brazil
# 23      24  Gabriel Martinelli         Left Winger   22  Brazil
# 24      25     Bruno Guimarães  Defensive Midfield   26  Brazil
#
#                 club  시장가치(억)
# 3        Real Madrid   1950.0
# 13       Real Madrid   1300.0
# 23        Arsenal FC   1105.0
# 24  Newcastle United   1105.0

# %%
df.groupby('nation')

# %%
g = df.groupby('nation')
g.size()
# Out:
# nation
# Argentina    2
# Brazil       4
# Ecuador      1
# England      5
# France       3
# Germany      2
# Nigeria      1
# Norway       2
# Portugal     1
# Spain        3
# Uruguay      1
# dtype: int64

# %%
g.count()
# Out:
#            number  name  position  age  club  시장가치(억)
# nation
# Argentina       2     2         2    2     2        2
# Brazil          4     4         4    4     4        4
# Ecuador         1     1         1    1     1        1
# England         5     5         5    5     5        5
# France          3     3         3    3     3        3
# Germany         2     2         2    2     2        2
# Nigeria         1     1         1    1     1        1
# Norway          2     2         2    2     2        2
# Portugal        1     1         1    1     1        1
# Spain           3     3         3    3     3        3
# Uruguay         1     1         1    1     1        1

# %%
# 수치형 데이터
g.sum()
# Out:
# <ipython-input-81-1ffdd0c26c0d>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#            number  age  시장가치(억)
# nation
# Argentina      28   49   2600.0
# Brazil         67   93   5460.0
# Ecuador        16   22   1170.0
# England        35  119   8190.0
# France         43   69   4680.0
# Germany        19   40   2730.0
# Nigeria         9   25   1430.0
# Norway         25   48   3510.0
# Portugal       22   24   1170.0
# Spain          46   67   3770.0
# Uruguay        15   25   1300.0

# %%
g['시장가치(억)'].sum()
# Out:
# nation
# Argentina    2600.0
# Brazil       5460.0
# Ecuador      1170.0
# England      8190.0
# France       4680.0
# Germany      2730.0
# Nigeria      1430.0
# Norway       3510.0
# Portugal     1170.0
# Spain        3770.0
# Uruguay      1300.0
# Name: 시장가치(억), dtype: float64

# %%
# 선수들의 몸값의 합이 큰 클럽별로 정렬
c = df.groupby('club')
c.sum()
# Out:
# <ipython-input-83-8a5b6756826b>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   c.sum()
#                      number  age  시장가치(억)
# club
# AC Milan                 22   24   1170.0
# Arsenal FC               62   93   5265.0
# Bayer 04 Leverkusen      13   20   1300.0
# Bayern Munich            18   50   2860.0
# Chelsea FC               16   22   1170.0
# FC Barcelona             35   40   2340.0
# Inter Milan               8   26   1430.0
# Manchester City          40   96   6370.0
# Newcastle United         25   26   1105.0
# Paris Saint-Germain       3   25   2340.0
# Real Madrid              74  134   9230.0
# SSC Napoli                9   25   1430.0

# %%
c.sum().sort_values('시장가치(억)', ascending=False)
# Out:
# <ipython-input-84-9b359271ebec>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   c.sum().sort_values('시장가치(억)', ascending=False)
#                      number  age  시장가치(억)
# club
# Real Madrid              74  134   9230.0
# Manchester City          40   96   6370.0
# Arsenal FC               62   93   5265.0
# Bayern Munich            18   50   2860.0
# FC Barcelona             35   40   2340.0
# Paris Saint-Germain       3   25   2340.0
# Inter Milan               8   26   1430.0
# SSC Napoli                9   25   1430.0
# Bayer 04 Leverkusen      13   20   1300.0
# AC Milan                 22   24   1170.0
# Chelsea FC               16   22   1170.0
# Newcastle United         25   26   1105.0

# %%
c['시장가치(억)'].sum().sort_values(ascending=False)
# Out:
# club
# Real Madrid            9230.0
# Manchester City        6370.0
# Arsenal FC             5265.0
# Bayern Munich          2860.0
# FC Barcelona           2340.0
# Paris Saint-Germain    2340.0
# Inter Milan            1430.0
# SSC Napoli             1430.0
# Bayer 04 Leverkusen    1300.0
# AC Milan               1170.0
# Chelsea FC             1170.0
# Newcastle United       1105.0
# Name: 시장가치(억), dtype: float64
