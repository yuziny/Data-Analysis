# %% [markdown]
# <a href="https://colab.research.google.com/github/yuziny/Data-Analysis/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%2B%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IRIS 데이터

# %%
import pandas as pd

# %%
import seaborn as sns
df_iris = sns.load_dataset('iris')

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import seaborn as sns
df_iris = sns.load_dataset('iris')
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# 컬럼 선택

# %%
df_iris[['sepal_length','species']]
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# 컬럼명 변경

# %%
# df.rename(columns={'col1':'new_col1', 'col2':'new_col2'}, inplace=True)

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_iris.rename(columns={'sepal_length':'A', 'sepal_width':'B'}, inplace=True)

# %%
df_iris.head()
# Out:
#      A    B  petal_length  petal_width species
# 0  5.1  3.5           1.4          0.2  setosa
# 1  4.9  3.0           1.4          0.2  setosa
# 2  4.7  3.2           1.3          0.2  setosa
# 3  4.6  3.1           1.5          0.2  setosa
# 4  5.0  3.6           1.4          0.2  setosa

# %% [markdown]
# 컬럼 추가

# %%
df_iris['A_plus_B'] = df_iris.A + df_iris.B

# %%
df_iris.head()
# Out:
#      A    B  petal_length  petal_width species  A_plus_B
# 0  5.1  3.5           1.4          0.2  setosa       8.6
# 1  4.9  3.0           1.4          0.2  setosa       7.9
# 2  4.7  3.2           1.3          0.2  setosa       7.9
# 3  4.6  3.1           1.5          0.2  setosa       7.7
# 4  5.0  3.6           1.4          0.2  setosa       8.6

# %% [markdown]
# # Series

# %%
type(df_iris.A)
# Out:
# pandas.core.series.Series

# %%
df_iris.A.mean()
# Out:
# 5.843333333333334

# %%
df_iris.A.unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
df_iris.A.nunique()
# Out:
# 35

# %%
df_iris.A.nlargest(10)
df_iris.nlargest(10, ['A','B'])
# Out:
#        A    B  petal_length  petal_width    species  A_plus_B
# 131  7.9  3.8           6.4          2.0  virginica      11.7
# 117  7.7  3.8           6.7          2.2  virginica      11.5
# 135  7.7  3.0           6.1          2.3  virginica      10.7
# 122  7.7  2.8           6.7          2.0  virginica      10.5
# 118  7.7  2.6           6.9          2.3  virginica      10.3
# 105  7.6  3.0           6.6          2.1  virginica      10.6
# 130  7.4  2.8           6.1          1.9  virginica      10.2
# 107  7.3  2.9           6.3          1.8  virginica      10.2
# 109  7.2  3.6           6.1          2.5  virginica      10.8
# 125  7.2  3.2           6.0          1.8  virginica      10.4

# %%
df_iris['A'].value_counts().head()
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# Name: A, dtype: int64

# %%
df_iris[['A','B']].value_counts().head()
# Out:
# A    B
# 5.8  2.7    4
# 5.1  3.8    3
# 6.5  3.0    3
# 6.9  3.1    3
# 6.7  3.1    3
# dtype: int64

# %%
df_iris['A'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: >

# %%
import seaborn as sns
df = sns.load_dataset('iris')

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species.nunique()
# Out:
# 3

# %%
df.species.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Index

# %%
import seaborn as sns
df = sns.load_dataset('taxis')

# %%
df.head(1)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1       1.6   7.0  2.15
#
#    tolls  total   color      payment      pickup_zone         dropoff_zone  \
# 0    0.0  12.95  yellow  credit card  Lenox Hill West  UN/Turtle Bay South
#
#   pickup_borough dropoff_borough
# 0      Manhattan       Manhattan

# %%
df.set_index('color', inplace=True)

# %%
df.head(1)
# Out:
#                     pickup             dropoff  passengers  distance  fare  \
# color
# yellow 2019-03-23 20:21:09 2019-03-23 20:27:24           1       1.6   7.0
#
#          tip  tolls  total      payment      pickup_zone         dropoff_zone  \
# color
# yellow  2.15    0.0  12.95  credit card  Lenox Hill West  UN/Turtle Bay South
#
#        pickup_borough dropoff_borough
# color
# yellow      Manhattan       Manhattan

# %%
df.reset_index(inplace=True)

# %%
df.head(1)
# Out:
#     color              pickup             dropoff  passengers  distance  fare  \
# 0  yellow 2019-03-23 20:21:09 2019-03-23 20:27:24           1       1.6   7.0
#
#     tip  tolls  total      payment      pickup_zone         dropoff_zone  \
# 0  2.15    0.0  12.95  credit card  Lenox Hill West  UN/Turtle Bay South
#
#   pickup_borough dropoff_borough
# 0      Manhattan       Manhattan

# %% [markdown]
# # Sort

# %%
df.sort_values('distance',ascending=False, inplace=True)

# %%
df.head()
# Out:
#        color              pickup             dropoff  passengers  distance  \
# 5364  yellow 2019-03-17 16:59:17 2019-03-17 18:04:08           2     36.70
# 4219  yellow 2019-03-08 20:07:54 2019-03-08 21:10:00           1     36.66
# 4050  yellow 2019-03-13 14:05:19 2019-03-13 15:01:16           6     33.76
# 5648   green 2019-03-19 14:21:35 2019-03-19 15:51:28           2     33.46
# 2397  yellow 2019-03-21 18:56:59 2019-03-21 19:49:58           1     30.23
#
#        fare    tip  tolls   total      payment        pickup_zone  \
# 5364  150.0   0.00  24.02  174.82         cash        JFK Airport
# 4219   96.5  10.00   5.76  113.56  credit card        JFK Airport
# 4050  143.5   0.00   0.00  144.30         cash  LaGuardia Airport
# 5648  150.0   0.00  18.90  169.70         cash      East Flushing
# 2397   52.0  13.11   5.76   78.67  credit card        JFK Airport
#
#                        dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#     color              pickup             dropoff  passengers  distance  fare  \
# 0  yellow 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1  yellow 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2  yellow 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3  yellow 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4  yellow 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
#
#     tip  tolls  total      payment            pickup_zone  \
# 0  2.15    0.0  12.95  credit card        Lenox Hill West
# 1  0.00    0.0   9.30         cash  Upper West Side South
# 2  2.36    0.0  14.16  credit card          Alphabet City
# 3  6.15    0.0  36.95  credit card              Hudson Sq
# 4  1.10    0.0  13.40  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...
