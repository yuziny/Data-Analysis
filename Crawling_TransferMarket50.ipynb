# %% [markdown]
# <a href="https://colab.research.google.com/github/yuziny/Data-Analysis/blob/main/Crawling_TransferMarket50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 첫페이지와 두번째 페이지의 50명 정보

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# requests.get()으로 url정보 요청
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}

number=[]
name=[]
position=[]
age=[]
nation=[]
team=[]
value=[]

# 두번째 페이지까지 크롤링
for i in range(1, 3):
    url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

    r = requests.get(url, headers=headers)
    r.status_code # 200

# %%
    soup = BeautifulSoup(r.text, 'html.parser') # r.cotent도 가능

    player_info = soup.find_all('tr', class_=['odd','even'])

    # player_info에서 'td'태그만 찾기
    for info in player_info:
        player = info.find_all('td')

        number.append(player[0].text)
        name.append(player[3].text)
        position.append(player[4].text)
        age.append(player[5].text)
        nation.append(player[6].img['alt'])
        team.append(player[7].img['alt'])
        value.append(player[8].text.strip())

    time.sleep(1)

    # pd.DataFrame()으로 저장
    df = pd.DataFrame(
        {'number':number,
         'name':name,
         'position':position,
         'age':age,
         'nation':nation,
         'team':team,
         'value':value
         }
    )
    df
# Out:
#    number                 name            position age     nation  \
# 0       1      Jude Bellingham  Attacking Midfield  20    England
# 1       2       Erling Haaland      Centre-Forward  23     Norway
# 2       3        Kylian Mbappé         Left Winger  25     France
# 3       4      Vinicius Junior         Left Winger  23     Brazil
# 4       5          Bukayo Saka        Right Winger  22    England
# 5       6        Jamal Musiala  Attacking Midfield  20    Germany
# 6       7           Phil Foden        Right Winger  23    England
# 7       8     Lautaro Martínez      Centre-Forward  26  Argentina
# 8       9       Victor Osimhen      Centre-Forward  25    Nigeria
# 9      10          Declan Rice  Defensive Midfield  24    England
# 10     11                Rodri  Defensive Midfield  27      Spain
# 11     12           Harry Kane      Centre-Forward  30    England
# 12     13        Florian Wirtz  Attacking Midfield  20    Germany
# ...

# %%
# df.to_csv()로 csv파일로 저장
df.to_csv('transfermarket50.csv', index=False)
